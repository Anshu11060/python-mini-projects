# %%
tasks = []

# %%
def add_task():
    task = input("enter task")
    tasks.append({"task":task , "completed":False})
    print("task added")

# %%
def view_task():
    if not tasks:
        print("no task added yet")
    else:
        print("\n YOUR TASKS")
        for idx,task in enumerate(tasks,1):
            status = "True" if task ["completed"] else "False"
            print(f"{idx}.{task['task']}[{status}]")

# %%
def mark_completed():
    view_task()
    try:
        num = int(input("Choose task number to mark as completed: "))
        if 1 <= num <= len(tasks):
            tasks[num - 1]["completed"] = True
            print("Task marked as completed!")
        else:
            print("Invalid task number.")
    except ValueError:
        print("Please enter a valid number.")

# %%
def delete_task():
    view_task()
    try:
        num = int(input("choose to mark"))
        if 1<= num <= len(tasks):
            deleted = tasks.pop(num-1)
            print(f"Deleted: {deleted['task']}")
        else:
            print("Invalid task number.")
    except ValueError:
        print("Please enter a valid number.")

# %%
print("-----------TO -DO APP-------------------------------------")
print("MENU")
print("1.ADD NEW TASK")
print("2. VIEW TASKS")
print("3. MARK TASK AS COMPLETED")
print("4. DELETE TASK")
print("5. EXIT")
while True:
    
    choice = input("enter your choice")
    if choice == "1":
        add_task()
    elif choice == "2":
        view_task()
    elif choice == "3":
        mark_completed()
    elif choice == "4":
        delete_task()
    elif choice == "5":
        print("HAVE A NICE DAY ..............GOODBYE")
        break
    else:
        print("invalid choice. try again")
# Out:
# -----------TO -DO APP-------------------------------------
# MENU
# 1.ADD NEW TASK
# 2. VIEW TASKS
# 3. MARK TASK AS COMPLETED
# 4. DELETE TASK
# 5. EXIT
# enter your choice 1
# enter task
# task added
# enter your choice 1
# enter task meditation
# task added
# enter your choice 2
#  YOUR TASKS
# 1.[False]
# 2.meditation[False]
# enter your choice 3
#  YOUR TASKS
# 1.[False]
# 2.meditation[False]
# Choose task number to mark as completed:  meditation
# Please enter a valid number.
# enter your choice 4
#  YOUR TASKS
# 1.[False]
# 2.meditation[False]
# choose to mark 5
# Invalid task number.
# enter your choice 5
# HAVE A NICE DAY ..............GOODBYE
